# %%
print("Hello World!!!")
# Out:
# Hello World!!!

# %%
name = input("What's your name?")
age = input("Enter your age: ")
print(name + ", you are " + age + " years old")
# Out:
# XYZ, you are 18 years old
